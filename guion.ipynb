# %% [markdown]
# * Introducción
#     * Google Colab: cómo conectarse y crear el primer notebook
#     * Jupyter Notebooks: comandos básicos sin usar mucho shortcut (código y markdown)
# * Python Core
#     * Sintaxis básica (no ayuda, usar Google)
#     * Variables: tipos básicos
#     * Operadores: aritméticos, comparación, lógicos
#     * Funciones incorporadas: conversión entre tipos, input, print, len, type, round
#     * Strings: formateo, split, concatenación
# * Listas, range y tuplas
#     * Creación y acceso. [::-1]
#     * Range, range a lista
#     * Métodos de listas: append, sort, reverse, sum, min, max, index, in, not in, copy
#     * Tuplas: creación y mapping
# * Diccionarios
#     * Creación y acceso
#     * Métodos: keys, values, items
# * Condicionales y bucles
#     * if, if else, elif
#     * for, for anidado
#     * while
#     * break, continue
# * Funciones
#     * Creación, parámetros, parámetros por defecto
#     * Especificación de tipos, documentación
#     * Contexto de las variables
# * Numpy
#     * Diferencia entre list y np.array/np.ndarray
#     * Creación de arrays 1D, 2D, 3D.
#         * arange, linspace, ones, zeros
#         * shape, reshape(-1), ndim, size, expand_dims
#         * acceso, acceso booleano, modificación, copy, sort
#         * concatenate, vstack, hstack, flatten
#     * Operaciones entre arrays
#         * +, -, *, /
#         * np.sum
#     * Operaciones entre arrays de distintas dimensiones, broadcasting
#     * Matrices
#         * min, max, sum, axis, T
#     * Números aleatorios
#         * np.random.default_rng, random, integers, shuffle, choice
#         * np.random.uniform
#         * np.random.normal
#         * np.random.chisquare
#     * Rendimiento for vs vectorial, %%timeit
# * Pandas
#     * Estructura de un DataFrame
#         * Creación via diccionario, lista de diccionarios
#         * Lectura/escritura de datos desde/a CSV (otros formatos: JSON, Excel, Parquet)
#         * Inspección de un DF, describe, info, head, tail, shape
#         * Acceso a index, columns, values
#         * Ordenación: sort_index, sort_values
#     * Selección de subconjuntos de datos sin y con loc, iloc
#         * Selección de columnas. Devolución de serie y dataframe
#         * Filtrado de filas con máscara booleana, más de una condición
#     * Graficado rápido: plot, plot.scatter, plot.hist, plot.box
#     * Funciones: count, unique, min, max, argmin, argmax, idxmin, idxmax, quantile, sum, mean, std, cumsum, pct_change, np.log, diff.
#         * Creación de nuevas columnas a partir de existentes.
#     * apply
#     * concat, join, merge, append
#     * groupby con sum, mean y std
# * Series temporales
# * Visualización
# * Tratamiento de datos
